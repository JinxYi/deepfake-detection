# %%
data_dir = "/scratch-shared/TANJ0303/datasets/"

# %%
# !export HF_DATASETS_CACHE=data_dir

# %%
import sys
import os

def is_colab_env():
    return "google.colab" in sys.modules

def mount_google_drive(drive_dir="/content/drive/", repo_dir="MyDrive/repositories/deepfake-detection"):
    # mount google drive
    from google.colab import drive
    drive.mount(drive_dir)

    # change to correct working directory
    import os
    os.chdir(f"{drive_dir}{repo_dir}")
    print(os.listdir()) # verify content

def resolve_path(levels_deep=3):
    if is_colab_env():
        mount_google_drive()
        return ""
    else:
        # Get the directory of the current script
        current_dir = os.path.dirname(os.path.abspath('__file__'))

        # Construct the path to the parent directory
        for i in range(levels_deep):
            current_dir = os.path.dirname(current_dir)

        # Add the parent directory to sys.path
        sys.path.append(current_dir)
        print(sys.path)
        return current_dir

proj_dir = resolve_path()
# Out:
# ['/home/FYP/tanj0303/.conda/envs/df-env/lib/python310.zip', '/home/FYP/tanj0303/.conda/envs/df-env/lib/python3.10', '/home/FYP/tanj0303/.conda/envs/df-env/lib/python3.10/lib-dynload', '', '/home/FYP/tanj0303/.conda/envs/df-env/lib/python3.10/site-packages', '/home/FYP/tanj0303']

# %%
# import local config
import config

# %%
# import library dependencies
import numpy as np

# %%
# pytorch
import torch
import pytorch_lightning as L

# %%
# import local dependencies
from src.adapters.datasets.wilddeepfake import WildDeepfakeDataModule
from src.models.resnet import ResNetClassifier

# %%
model_id = "fft_magnitude_phase_resnet18"
model_checkpoint_dir = f"{proj_dir}/{config.CHECKPOINTS_DIR}/{model_id}"

# %%
from src.transforms.frequency import get_transforms
fft_mag_phase_transforms = get_transforms("fft_mag_phase")

# %%
# max_samples = 800_000  # For quick development, remove for full dataset
batch_size = 32
num_workers = 20
seed = config.SEED

# Set seeds for reproducibility
torch.manual_seed(seed)
np.random.seed(seed)

# Determine device (GPU or CPU)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# define datamodule
wilddeepfake_data_module = WildDeepfakeDataModule(
    batch_size=batch_size,
    num_workers=num_workers,
    # max_samples=max_samples,
    seed=seed,
    transforms=fft_mag_phase_transforms,
    dataset_cache_dir=data_dir
)
# Out:
# Using device: cuda

# %%
# define early stopper
early_stop_callback = L.callbacks.EarlyStopping(
    monitor="val_loss",       # metric to track
    patience=3,               # epochs to wait for improvement
    mode="min",               # "min" because we want val_loss to decrease
    verbose=True
)

# %%
# define ligntning checkpoint
best_loss_checkpoint = L.callbacks.ModelCheckpoint(
    monitor="val_loss",
    mode="min",
    save_top_k=1,
)

# %%
# define model
checkpoint = "lightning_logs/version_2/checkpoints/epoch=8-step=228240.ckpt"
deepfake_detector = ResNetClassifier.load_from_checkpoint(f"{model_checkpoint_dir}/{checkpoint}")

# %%
# define trainer
max_epochs = 100
trainer = L.Trainer(
    devices=1,
    callbacks=[early_stop_callback, best_loss_checkpoint],
    default_root_dir=model_checkpoint_dir,
    log_every_n_steps=100,
    profiler="simple", # track time taken
    max_epochs=max_epochs,
  )
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# /home/FYP/tanj0303/.conda/envs/df-env/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/logger_connector.py:76: Starting from v1.9.0, `tensorboardX` has been removed as a dependency of the `pytorch_lightning` package, due to potential conflicts with other packages in the ML ecosystem. For this reason, `logger=True` will use `CSVLogger` as the default logger, unless the `tensorboard` or `tensorboardX` packages are found. Please `pip install lightning[extra]` or one of them to enable TensorBoard support by default

# %%
# test dataset on unseen samples
trainer.test(deepfake_detector, datamodule=wilddeepfake_data_module)
# trainer.test(deepfake_detector, test_loader)
# Out:
# Resolving data files:   0%|          | 0/963 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/157 [00:00<?, ?it/s]
# Loading dataset shards:   0%|          | 0/124 [00:00<?, ?it/s]
# Loading dataset shards:   0%|          | 0/20 [00:00<?, ?it/s]
# Dataset loaded. Processing samples...
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# SLURM auto-requeueing enabled. Setting signal handlers.
# Extracted labels. Generating train/val split...
# Train samples: 811549, Val samples: 202888, Test samples: 165662
# Testing: |          | 0/? [00:00<?, ?it/s]
# TEST Profiler Report
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Action                                                                                                                                                         	|  Mean duration (s)	|  Num calls      	|  Total time (s) 	|  Percentage %   	|
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Total                                                                                                                                                          	|  -              	|  82869          	|  141.89         	|  100 %          	|
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  [Strategy]SingleDeviceStrategy.test_step                                                                                                                       	|  0.022027       	|  5177           	|  114.03         	|  80.371         	|
# |  [LightningDataModule]WildDeepfakeDataModule.setup                                                                                                              	|  16.62          	|  1              	|  16.62          	|  11.714         	|
# |  [Callback]TQDMProgressBar.on_test_batch_end                                                                                                                    	|  0.0005184      	|  5177           	|  2.6838         	|  1.8915         	|
# |  [_EvaluationLoop].test_next                                                                                                                                    	|  0.00041547     	|  5177           	|  2.1509         	|  1.5159         	|
# |  [Strategy]SingleDeviceStrategy.batch_to_device                                                                                                                 	|  0.00016454     	|  5177           	|  0.85182        	|  0.60035        	|
# |  [LightningModule]ResNetClassifier.transfer_batch_to_device                                                                                                     	|  0.00010547     	|  5177           	|  0.54602        	|  0.38483        	|
# |  [Callback]ModelSummary.on_test_batch_end                                                                                                                       	|  3.6705e-06     	|  5177           	|  0.019002       	|  0.013392       	|
# |  [Callback]TQDMProgressBar.on_test_batch_start                                                                                                                  	|  3.5845e-06     	|  5177           	|  0.018557       	|  0.013079       	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_test_batch_end                                                                                	|  2.9153e-06     	|  5177           	|  0.015093       	|  0.010637       	|
# |  [Callback]TQDMProgressBar.on_test_start                                                                                                                        	|  0.01373        	|  1              	|  0.01373        	|  0.009677       	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_test_batch_start                                                                              	|  2.2446e-06     	|  5177           	|  0.01162        	|  0.0081899      	|
# |  [LightningModule]ResNetClassifier.on_before_batch_transfer                                                                                                     	|  1.8613e-06     	|  5177           	|  0.0096358      	|  0.0067912      	|
# |  [LightningModule]ResNetClassifier.on_test_batch_end                                                                                                            	|  1.526e-06      	|  5177           	|  0.0079         	|  0.0055678      	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_batch_end  	|  1.5077e-06     	|  5177           	|  0.0078051      	|  0.005501       	|
# |  [Callback]ModelSummary.on_test_batch_start                                                                                                                     	|  1.2924e-06     	|  5177           	|  0.0066906      	|  0.0047155      	|
# |  [LightningModule]ResNetClassifier.on_after_batch_transfer                                                                                                      	|  1.2662e-06     	|  5177           	|  0.006555       	|  0.0046199      	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_batch_start	|  1.2292e-06     	|  5177           	|  0.0063636      	|  0.004485       	|
# |  [LightningModule]ResNetClassifier.on_test_batch_start                                                                                                          	|  1.1628e-06     	|  5177           	|  0.0060198      	|  0.0042427      	|
# |  [LightningModule]ResNetClassifier.on_test_model_eval                                                                                                           	|  0.00071223     	|  1              	|  0.00071223     	|  0.00050198     	|
# |  [Callback]TQDMProgressBar.on_test_end                                                                                                                          	|  0.00059576     	|  1              	|  0.00059576     	|  0.00041989     	|
# |  [LightningDataModule]WildDeepfakeDataModule.test_dataloader                                                                                                    	|  0.00029469     	|  1              	|  0.00029469     	|  0.00020769     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.setup              	|  0.00010166     	|  1              	|  0.00010166     	|  7.1645e-05     	|
# |  [Callback]ModelSummary.on_test_start                                                                                                                           	|  8.9649e-06     	|  1              	|  8.9649e-06     	|  6.3184e-06     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_test_epoch_start                                                                              	|  5.452e-06      	|  1              	|  5.452e-06      	|  3.8425e-06     	|
# |  [LightningModule]ResNetClassifier.on_test_epoch_start                                                                                                          	|  4.6149e-06     	|  1              	|  4.6149e-06     	|  3.2526e-06     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.setup                                                                                            	|  4.5181e-06     	|  1              	|  4.5181e-06     	|  3.1843e-06     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_test_end                                                                                      	|  4.0189e-06     	|  1              	|  4.0189e-06     	|  2.8325e-06     	|
# |  [Callback]TQDMProgressBar.setup                                                                                                                                	|  3.9858e-06     	|  1              	|  3.9858e-06     	|  2.8092e-06     	|
# |  [Strategy]SingleDeviceStrategy.on_test_start                                                                                                                   	|  3.9379e-06     	|  1              	|  3.9379e-06     	|  2.7754e-06     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_test_epoch_end                                                                                	|  3.777e-06      	|  1              	|  3.777e-06      	|  2.662e-06      	|
# |  [LightningDataModule]WildDeepfakeDataModule.teardown                                                                                                           	|  3.5211e-06     	|  1              	|  3.5211e-06     	|  2.4816e-06     	|
# |  [Callback]ModelSummary.on_test_end                                                                                                                             	|  3.2161e-06     	|  1              	|  3.2161e-06     	|  2.2667e-06     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_test_start                                                                                    	|  2.9819e-06     	|  1              	|  2.9819e-06     	|  2.1016e-06     	|
# |  [LightningModule]ResNetClassifier.configure_callbacks                                                                                                          	|  2.7209e-06     	|  1              	|  2.7209e-06     	|  1.9176e-06     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.teardown                                                                                         	|  2.542e-06      	|  1              	|  2.542e-06      	|  1.7916e-06     	|
# |  [Strategy]SingleDeviceStrategy.on_test_end                                                                                                                     	|  2.234e-06      	|  1              	|  2.234e-06      	|  1.5745e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_start      	|  2.017e-06      	|  1              	|  2.017e-06      	|  1.4216e-06     	|
# |  [Callback]ModelSummary.setup                                                                                                                                   	|  1.9402e-06     	|  1              	|  1.9402e-06     	|  1.3674e-06     	|
# |  [Callback]TQDMProgressBar.on_test_epoch_start                                                                                                                  	|  1.6082e-06     	|  1              	|  1.6082e-06     	|  1.1334e-06     	|
# |  [LightningModule]ResNetClassifier.on_test_start                                                                                                                	|  1.576e-06      	|  1              	|  1.576e-06      	|  1.1108e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_epoch_start	|  1.569e-06      	|  1              	|  1.569e-06      	|  1.1058e-06     	|
# |  [Callback]ModelSummary.on_test_epoch_start                                                                                                                     	|  1.505e-06      	|  1              	|  1.505e-06      	|  1.0607e-06     	|
# |  [LightningModule]ResNetClassifier.on_test_end                                                                                                                  	|  1.424e-06      	|  1              	|  1.424e-06      	|  1.0036e-06     	|
# |  [LightningModule]ResNetClassifier.on_test_epoch_end                                                                                                            	|  1.4098e-06     	|  1              	|  1.4098e-06     	|  9.9361e-07     	|
# |  [Callback]TQDMProgressBar.teardown                                                                                                                             	|  1.404e-06      	|  1              	|  1.404e-06      	|  9.895e-07      	|
# |  [LightningModule]ResNetClassifier.setup                                                                                                                        	|  1.3181e-06     	|  1              	|  1.3181e-06     	|  9.2895e-07     	|
# |  [Callback]TQDMProgressBar.on_test_epoch_end                                                                                                                    	|  1.2538e-06     	|  1              	|  1.2538e-06     	|  8.8366e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_epoch_end  	|  1.248e-06      	|  1              	|  1.248e-06      	|  8.7956e-07     	|
# |  [Callback]ModelSummary.teardown                                                                                                                                	|  1.204e-06      	|  1              	|  1.204e-06      	|  8.4854e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_end        	|  1.0438e-06     	|  1              	|  1.0438e-06     	|  7.3565e-07     	|
# |  [LightningModule]ResNetClassifier.teardown                                                                                                                     	|  1.0051e-06     	|  1              	|  1.0051e-06     	|  7.0841e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.teardown           	|  9.9116e-07     	|  1              	|  9.9116e-07     	|  6.9856e-07     	|
# |  [Callback]ModelSummary.on_test_epoch_end                                                                                                                       	|  9.5507e-07     	|  1              	|  9.5507e-07     	|  6.7313e-07     	|
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test_acc            0.6702864766120911
#         test_auc            0.7311519384384155
#          test_f1            0.7295467853546143
#         test_loss            0.70676189661026
#         test_prec           0.7758166790008545
#         test_rec            0.6884853839874268
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# [{'test_acc': 0.6702864766120911,
#   'test_prec': 0.7758166790008545,
#   'test_rec': 0.6884853839874268,
#   'test_f1': 0.7295467853546143,
#   'test_auc': 0.7311519384384155,
#   'test_loss': 0.70676189661026}]
