# %%
import sys
import os

def is_colab_env():
    return "google.colab" in sys.modules

def mount_google_drive(drive_dir="/content/drive/", repo_dir="MyDrive/repositories/deepfake-detection"):
    # mount google drive
    from google.colab import drive
    drive.mount(drive_dir)

    # change to correct working directory
    import os
    os.chdir(f"{drive_dir}{repo_dir}")
    print(os.listdir()) # verify content

def resolve_path(levels_deep=3):
    if is_colab_env():
        mount_google_drive()
    else:
        # Get the directory of the current script
        current_dir = os.path.dirname(os.path.abspath('__file__'))

        # Construct the path to the parent directory
        for i in range(levels_deep):
            current_dir = os.path.dirname(current_dir)

        # Add the parent directory to sys.path
        sys.path.append(current_dir)
        print(sys.path)

resolve_path()
# Out:
# ['/home/FYP/tanj0303/.conda/envs/df-env/lib/python310.zip', '/home/FYP/tanj0303/.conda/envs/df-env/lib/python3.10', '/home/FYP/tanj0303/.conda/envs/df-env/lib/python3.10/lib-dynload', '', '/home/FYP/tanj0303/.conda/envs/df-env/lib/python3.10/site-packages', '/home/FYP/tanj0303']

# %%
data_dir = "/scratch-shared/TANJ0303/datasets/"

# import local config
import config
model_id = "fft_magnitude_phase_resnet18"
model_checkpoint_dir = f"{config.CHECKPOINTS_DIR}/{model_id}"
checkpoint = "lightning_logs/version_1/checkpoints/epoch=4-step=126800.ckpt"

# %%
# import local dependencies
from src.adapters.datasets.wilddeepfake import WildDeepfakeDataModule
from src.models.resnet import ResNetClassifier

# %%
import pytorch_lightning as L

# %%
import torch

# %%
deepfake_detector = ResNetClassifier.load_from_checkpoint(f"{model_checkpoint_dir}/{checkpoint}")

# %%
# define trainer
# max_steps ~ (num_samples // batch_size) * num_epochs
max_epochs = 100
trainer = L.Trainer(
    devices=1,
    # callbacks=[early_stop_callback, best_loss_checkpoint],
    default_root_dir=model_checkpoint_dir,
    log_every_n_steps=10,
    profiler="simple", # track time taken
    # max_steps=31_250,
    # max_steps= max_epochs * max_samples / batch_size,
    max_epochs=max_epochs,
    # limit_train_batches=1000,   # how many batches per "epoch"
    # limit_val_batches=200,      # how many val batches per "epoch"
  )
# Out:
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# /home/FYP/tanj0303/.conda/envs/df-env/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/logger_connector.py:76: Starting from v1.9.0, `tensorboardX` has been removed as a dependency of the `pytorch_lightning` package, due to potential conflicts with other packages in the ML ecosystem. For this reason, `logger=True` will use `CSVLogger` as the default logger, unless the `tensorboard` or `tensorboardX` packages are found. Please `pip install lightning[extra]` or one of them to enable TensorBoard support by default

# %%
from src.transforms.frequency import get_transforms
fft_mag_phase_transforms = get_transforms("fft_ri")

# %%
# max_samples = 800_000  # For quick development, remove for full dataset
batch_size = 16
num_workers = 4
seed = config.SEED

# Determine device (GPU or CPU)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# define datamodule
wilddeepfake_data_module = WildDeepfakeDataModule(
    batch_size=batch_size,
    num_workers=num_workers,
    # max_samples=max_samples,
    seed=seed,
    transforms=fft_mag_phase_transforms,
    dataset_cache_dir=data_dir
)
# Out:
# Using device: cuda

# %%
trainer.test(deepfake_detector, datamodule=wilddeepfake_data_module)
# Out:
# Resolving data files:   0%|          | 0/963 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/157 [00:00<?, ?it/s]
# Loading dataset shards:   0%|          | 0/124 [00:00<?, ?it/s]
# Loading dataset shards:   0%|          | 0/20 [00:00<?, ?it/s]
# Dataset loaded. Processing samples...
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# SLURM auto-requeueing enabled. Setting signal handlers.
# Extracted labels. Generating train/val split...
# Train samples: 811549, Val samples: 202888, Test samples: 165662
# Testing: |          | 0/? [00:00<?, ?it/s]
# TEST Profiler Report
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Action                                                                                                                                                   	|  Mean duration (s)	|  Num calls      	|  Total time (s) 	|  Percentage %   	|
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Total                                                                                                                                                    	|  -              	|  144987         	|  230.84         	|  100 %          	|
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  [Strategy]SingleDeviceStrategy.test_step                                                                                                                 	|  0.018578       	|  10354          	|  192.35         	|  83.326         	|
# |  [_EvaluationLoop].test_next                                                                                                                              	|  0.0020266      	|  10354          	|  20.983         	|  9.09           	|
# |  [LightningDataModule]WildDeepfakeDataModule.setup                                                                                                        	|  6.1772         	|  1              	|  6.1772         	|  2.6759         	|
# |  [Callback]TQDMProgressBar.on_test_batch_end                                                                                                              	|  0.00033731     	|  10354          	|  3.4925         	|  1.5129         	|
# |  [Strategy]SingleDeviceStrategy.batch_to_device                                                                                                           	|  0.00012551     	|  10354          	|  1.2995         	|  0.56295        	|
# |  [LightningModule]ResNetClassifier.transfer_batch_to_device                                                                                               	|  7.9618e-05     	|  10354          	|  0.82436        	|  0.35711        	|
# |  [Callback]ModelSummary.on_test_batch_end                                                                                                                 	|  4.5438e-06     	|  10354          	|  0.047046       	|  0.02038        	|
# |  [Callback]TQDMProgressBar.on_test_batch_start                                                                                                            	|  3.3727e-06     	|  10354          	|  0.034921       	|  0.015128       	|
# |  [LightningModule]ResNetClassifier.on_before_batch_transfer                                                                                               	|  1.4715e-06     	|  10354          	|  0.015236       	|  0.0066003      	|
# |  [Callback]ModelSummary.on_test_batch_start                                                                                                               	|  1.4466e-06     	|  10354          	|  0.014978       	|  0.0064885      	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_batch_end  	|  1.4101e-06     	|  10354          	|  0.0146         	|  0.0063249      	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_batch_start	|  1.1715e-06     	|  10354          	|  0.01213        	|  0.0052548      	|
# |  [LightningModule]ResNetClassifier.on_test_batch_end                                                                                                      	|  1.0795e-06     	|  10354          	|  0.011177       	|  0.004842       	|
# |  [Callback]TQDMProgressBar.on_test_start                                                                                                                  	|  0.011111       	|  1              	|  0.011111       	|  0.0048132      	|
# |  [LightningModule]ResNetClassifier.on_test_batch_start                                                                                                    	|  1.0017e-06     	|  10354          	|  0.010372       	|  0.0044931      	|
# |  [LightningModule]ResNetClassifier.on_after_batch_transfer                                                                                                	|  9.9051e-07     	|  10354          	|  0.010256       	|  0.0044428      	|
# |  [Callback]TQDMProgressBar.on_test_end                                                                                                                    	|  0.00061283     	|  1              	|  0.00061283     	|  0.00026548     	|
# |  [LightningModule]ResNetClassifier.on_test_model_eval                                                                                                     	|  0.0005371      	|  1              	|  0.0005371      	|  0.00023267     	|
# |  [LightningDataModule]WildDeepfakeDataModule.test_dataloader                                                                                              	|  0.0003413      	|  1              	|  0.0003413      	|  0.00014785     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.setup              	|  0.00011278     	|  1              	|  0.00011278     	|  4.8857e-05     	|
# |  [Callback]ModelSummary.on_test_end                                                                                                                       	|  5.885e-06      	|  1              	|  5.885e-06      	|  2.5494e-06     	|
# |  [Callback]ModelSummary.on_test_start                                                                                                                     	|  5.6371e-06     	|  1              	|  5.6371e-06     	|  2.442e-06      	|
# |  [Callback]TQDMProgressBar.setup                                                                                                                          	|  5.5281e-06     	|  1              	|  5.5281e-06     	|  2.3948e-06     	|
# |  [Strategy]SingleDeviceStrategy.on_test_end                                                                                                               	|  4.2182e-06     	|  1              	|  4.2182e-06     	|  1.8273e-06     	|
# |  [Callback]TQDMProgressBar.on_test_epoch_end                                                                                                              	|  3.8422e-06     	|  1              	|  3.8422e-06     	|  1.6644e-06     	|
# |  [Strategy]SingleDeviceStrategy.on_test_start                                                                                                             	|  3.2629e-06     	|  1              	|  3.2629e-06     	|  1.4135e-06     	|
# |  [LightningModule]ResNetClassifier.on_test_epoch_start                                                                                                    	|  2.9169e-06     	|  1              	|  2.9169e-06     	|  1.2636e-06     	|
# |  [LightningDataModule]WildDeepfakeDataModule.teardown                                                                                                     	|  2.7739e-06     	|  1              	|  2.7739e-06     	|  1.2017e-06     	|
# |  [LightningModule]ResNetClassifier.configure_callbacks                                                                                                    	|  2.6349e-06     	|  1              	|  2.6349e-06     	|  1.1415e-06     	|
# |  [Callback]TQDMProgressBar.teardown                                                                                                                       	|  2.1858e-06     	|  1              	|  2.1858e-06     	|  9.4689e-07     	|
# |  [Callback]ModelSummary.setup                                                                                                                             	|  1.75e-06       	|  1              	|  1.75e-06       	|  7.5808e-07     	|
# |  [LightningModule]ResNetClassifier.on_test_epoch_end                                                                                                      	|  1.55e-06       	|  1              	|  1.55e-06       	|  6.7144e-07     	|
# |  [LightningModule]ResNetClassifier.setup                                                                                                                  	|  1.5411e-06     	|  1              	|  1.5411e-06     	|  6.676e-07      	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_start      	|  1.4191e-06     	|  1              	|  1.4191e-06     	|  6.1475e-07     	|
# |  [LightningModule]ResNetClassifier.on_test_start                                                                                                          	|  1.3299e-06     	|  1              	|  1.3299e-06     	|  5.7612e-07     	|
# |  [Callback]ModelSummary.on_test_epoch_end                                                                                                                 	|  1.3059e-06     	|  1              	|  1.3059e-06     	|  5.6573e-07     	|
# |  [Callback]TQDMProgressBar.on_test_epoch_start                                                                                                            	|  1.241e-06      	|  1              	|  1.241e-06      	|  5.3759e-07     	|
# |  [Callback]ModelSummary.teardown                                                                                                                          	|  1.2289e-06     	|  1              	|  1.2289e-06     	|  5.3235e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_end        	|  1.17e-06       	|  1              	|  1.17e-06       	|  5.0683e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_epoch_start	|  1.0971e-06     	|  1              	|  1.0971e-06     	|  4.7526e-07     	|
# |  [LightningModule]ResNetClassifier.on_test_end                                                                                                            	|  1.085e-06      	|  1              	|  1.085e-06      	|  4.7002e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.teardown           	|  1.065e-06      	|  1              	|  1.065e-06      	|  4.6134e-07     	|
# |  [LightningModule]ResNetClassifier.teardown                                                                                                               	|  1.0619e-06     	|  1              	|  1.0619e-06     	|  4.6003e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_epoch_end  	|  1.0498e-06     	|  1              	|  1.0498e-06     	|  4.5479e-07     	|
# |  [Callback]ModelSummary.on_test_epoch_start                                                                                                               	|  1.0328e-06     	|  1              	|  1.0328e-06     	|  4.4742e-07     	|
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test_acc            0.7016696929931641
#         test_auc             0.751889705657959
#          test_f1            0.7702947854995728
#         test_loss           0.5971395969390869
#         test_prec           0.7662065029144287
#         test_rec            0.7744268774986267
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# [{'test_acc': 0.7016696929931641,
#   'test_prec': 0.7662065029144287,
#   'test_rec': 0.7744268774986267,
#   'test_f1': 0.7702947854995728,
#   'test_auc': 0.751889705657959,
#   'test_loss': 0.5971395969390869}]
