# %%
import sys
import os

def is_colab_env():
    return "google.colab" in sys.modules

def mount_google_drive(drive_dir="/content/drive/", repo_dir="MyDrive/repositories/deepfake-detection"):
    # mount google drive
    from google.colab import drive
    drive.mount(drive_dir)

    # change to correct working directory
    import os
    os.chdir(f"{drive_dir}{repo_dir}")
    print(os.listdir()) # verify content

def resolve_path(levels_deep=3):
    if is_colab_env():
        mount_google_drive()
    else:
        # Get the directory of the current script
        current_dir = os.path.dirname(os.path.abspath('__file__'))

        # Construct the path to the parent directory
        for i in range(levels_deep):
            current_dir = os.path.dirname(current_dir)

        # Add the parent directory to sys.path
        sys.path.append(current_dir)
        print(sys.path)

resolve_path()
# Out:
# ['/home/FYP/tanj0303/.conda/envs/df-env/lib/python310.zip', '/home/FYP/tanj0303/.conda/envs/df-env/lib/python3.10', '/home/FYP/tanj0303/.conda/envs/df-env/lib/python3.10/lib-dynload', '', '/home/FYP/tanj0303/.conda/envs/df-env/lib/python3.10/site-packages', '/home/FYP/tanj0303']

# %%
data_dir = "/scratch-shared/TANJ0303/datasets/"

# import local config
import config
model_id = "fft_magnitude_phase_resnet18"
model_checkpoint_dir = f"{config.CHECKPOINTS_DIR}/{model_id}"
checkpoint = "lightning_logs/version_0/checkpoints/epoch=3-step=202884.ckpt"

# %%
# import local dependencies
from src.adapters.datasets.wilddeepfake import WildDeepfakeDataModule
from src.models.resnet import ResNetClassifier

# %%
import pytorch_lightning as L

# %%
import torch

# %%
deepfake_detector = ResNetClassifier.load_from_checkpoint(f"{model_checkpoint_dir}/{checkpoint}")

# %%
# define trainer
# max_steps ~ (num_samples // batch_size) * num_epochs
max_epochs = 100
trainer = L.Trainer(
    devices=1,
    # callbacks=[early_stop_callback, best_loss_checkpoint],
    default_root_dir=model_checkpoint_dir,
    log_every_n_steps=10,
    profiler="simple", # track time taken
    # max_steps=31_250,
    # max_steps= max_epochs * max_samples / batch_size,
    max_epochs=max_epochs,
    # limit_train_batches=1000,   # how many batches per "epoch"
    # limit_val_batches=200,      # how many val batches per "epoch"
  )
# Out:
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# /home/FYP/tanj0303/.conda/envs/df-env/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/logger_connector.py:76: Starting from v1.9.0, `tensorboardX` has been removed as a dependency of the `pytorch_lightning` package, due to potential conflicts with other packages in the ML ecosystem. For this reason, `logger=True` will use `CSVLogger` as the default logger, unless the `tensorboard` or `tensorboardX` packages are found. Please `pip install lightning[extra]` or one of them to enable TensorBoard support by default

# %%
from src.transforms.frequency import get_transforms
fft_mag_phase_transforms = get_transforms("fft_ri")

# %%
# max_samples = 800_000  # For quick development, remove for full dataset
batch_size = 16
num_workers = 4
seed = config.SEED

# Determine device (GPU or CPU)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# define datamodule
wilddeepfake_data_module = WildDeepfakeDataModule(
    batch_size=batch_size,
    num_workers=num_workers,
    # max_samples=max_samples,
    seed=seed,
    transforms=fft_mag_phase_transforms,
    dataset_cache_dir=data_dir
)
# Out:
# Using device: cuda

# %%
trainer.test(deepfake_detector, datamodule=wilddeepfake_data_module)
# Out:
# Resolving data files:   0%|          | 0/963 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/157 [00:00<?, ?it/s]
# Loading dataset shards:   0%|          | 0/124 [00:00<?, ?it/s]
# Loading dataset shards:   0%|          | 0/20 [00:00<?, ?it/s]
# Dataset loaded. Processing samples...
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# SLURM auto-requeueing enabled. Setting signal handlers.
# Extracted labels. Generating train/val split...
# Train samples: 811549, Val samples: 202888, Test samples: 165662
# Testing: |          | 0/? [00:00<?, ?it/s]
# TEST Profiler Report
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Action                                                                                                                                                   	|  Mean duration (s)	|  Num calls      	|  Total time (s) 	|  Percentage %   	|
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Total                                                                                                                                                    	|  -              	|  144987         	|  410.61         	|  100 %          	|
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  [Strategy]SingleDeviceStrategy.test_step                                                                                                                 	|  0.024624       	|  10354          	|  254.96         	|  62.092         	|
# |  [_EvaluationLoop].test_next                                                                                                                              	|  0.0023601      	|  10354          	|  24.436         	|  5.9512         	|
# |  [Strategy]SingleDeviceStrategy.batch_to_device                                                                                                           	|  0.001706       	|  10354          	|  17.664         	|  4.3019         	|
# |  [LightningModule]ResNetClassifier.transfer_batch_to_device                                                                                               	|  0.0016276      	|  10354          	|  16.852         	|  4.1041         	|
# |  [LightningDataModule]WildDeepfakeDataModule.setup                                                                                                        	|  6.5393         	|  1              	|  6.5393         	|  1.5926         	|
# |  [Callback]TQDMProgressBar.on_test_batch_end                                                                                                              	|  0.00048178     	|  10354          	|  4.9883         	|  1.2149         	|
# |  [Callback]TQDMProgressBar.on_test_batch_start                                                                                                            	|  4.7209e-06     	|  10354          	|  0.04888        	|  0.011904       	|
# |  [Callback]ModelSummary.on_test_batch_end                                                                                                                 	|  3.7789e-06     	|  10354          	|  0.039126       	|  0.0095288      	|
# |  [Callback]TQDMProgressBar.on_test_start                                                                                                                  	|  0.027316       	|  1              	|  0.027316       	|  0.0066525      	|
# |  [LightningModule]ResNetClassifier.on_before_batch_transfer                                                                                               	|  2.275e-06      	|  10354          	|  0.023555       	|  0.0057366      	|
# |  [Callback]ModelSummary.on_test_batch_start                                                                                                               	|  1.9074e-06     	|  10354          	|  0.019749       	|  0.0048098      	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_batch_end  	|  1.6223e-06     	|  10354          	|  0.016797       	|  0.0040907      	|
# |  [LightningModule]ResNetClassifier.on_after_batch_transfer                                                                                                	|  1.5848e-06     	|  10354          	|  0.016409       	|  0.0039963      	|
# |  [LightningModule]ResNetClassifier.on_test_batch_end                                                                                                      	|  1.4991e-06     	|  10354          	|  0.015522       	|  0.0037801      	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_batch_start	|  1.3309e-06     	|  10354          	|  0.01378        	|  0.003356       	|
# |  [LightningModule]ResNetClassifier.on_test_batch_start                                                                                                    	|  1.2127e-06     	|  10354          	|  0.012556       	|  0.0030578      	|
# |  [LightningDataModule]WildDeepfakeDataModule.test_dataloader                                                                                              	|  0.00088832     	|  1              	|  0.00088832     	|  0.00021634     	|
# |  [LightningModule]ResNetClassifier.on_test_model_eval                                                                                                     	|  0.0007266      	|  1              	|  0.0007266      	|  0.00017696     	|
# |  [Callback]TQDMProgressBar.on_test_end                                                                                                                    	|  0.00071654     	|  1              	|  0.00071654     	|  0.0001745      	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.setup              	|  0.00053593     	|  1              	|  0.00053593     	|  0.00013052     	|
# |  [Callback]TQDMProgressBar.setup                                                                                                                          	|  2.2492e-05     	|  1              	|  2.2492e-05     	|  5.4777e-06     	|
# |  [Callback]ModelSummary.on_test_start                                                                                                                     	|  1.0704e-05     	|  1              	|  1.0704e-05     	|  2.6068e-06     	|
# |  [Callback]TQDMProgressBar.on_test_epoch_start                                                                                                            	|  8.224e-06      	|  1              	|  8.224e-06      	|  2.0029e-06     	|
# |  [LightningModule]ResNetClassifier.setup                                                                                                                  	|  4.93e-06       	|  1              	|  4.93e-06       	|  1.2006e-06     	|
# |  [Strategy]SingleDeviceStrategy.on_test_start                                                                                                             	|  4.1251e-06     	|  1              	|  4.1251e-06     	|  1.0046e-06     	|
# |  [Callback]TQDMProgressBar.on_test_epoch_end                                                                                                              	|  4.0049e-06     	|  1              	|  4.0049e-06     	|  9.7535e-07     	|
# |  [LightningDataModule]WildDeepfakeDataModule.teardown                                                                                                     	|  3.814e-06      	|  1              	|  3.814e-06      	|  9.2886e-07     	|
# |  [LightningModule]ResNetClassifier.on_test_epoch_start                                                                                                    	|  3.7351e-06     	|  1              	|  3.7351e-06     	|  9.0963e-07     	|
# |  [LightningModule]ResNetClassifier.configure_callbacks                                                                                                    	|  3.482e-06      	|  1              	|  3.482e-06      	|  8.48e-07       	|
# |  [Callback]ModelSummary.on_test_end                                                                                                                       	|  2.973e-06      	|  1              	|  2.973e-06      	|  7.2404e-07     	|
# |  [Callback]TQDMProgressBar.teardown                                                                                                                       	|  2.427e-06      	|  1              	|  2.427e-06      	|  5.9107e-07     	|
# |  [Callback]ModelSummary.setup                                                                                                                             	|  2.2368e-06     	|  1              	|  2.2368e-06     	|  5.4475e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_start      	|  1.7819e-06     	|  1              	|  1.7819e-06     	|  4.3395e-07     	|
# |  [LightningModule]ResNetClassifier.on_test_epoch_end                                                                                                      	|  1.549e-06      	|  1              	|  1.549e-06      	|  3.7725e-07     	|
# |  [Callback]ModelSummary.on_test_epoch_start                                                                                                               	|  1.3739e-06     	|  1              	|  1.3739e-06     	|  3.3461e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_epoch_start	|  1.369e-06      	|  1              	|  1.369e-06      	|  3.3341e-07     	|
# |  [Callback]ModelSummary.teardown                                                                                                                          	|  1.349e-06      	|  1              	|  1.349e-06      	|  3.2854e-07     	|
# |  [LightningModule]ResNetClassifier.on_test_start                                                                                                          	|  1.3439e-06     	|  1              	|  1.3439e-06     	|  3.2729e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_end        	|  1.211e-06      	|  1              	|  1.211e-06      	|  2.9491e-07     	|
# |  [Callback]ModelSummary.on_test_epoch_end                                                                                                                 	|  1.203e-06      	|  1              	|  1.203e-06      	|  2.9299e-07     	|
# |  [LightningModule]ResNetClassifier.teardown                                                                                                               	|  1.166e-06      	|  1              	|  1.166e-06      	|  2.8397e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.teardown           	|  1.1399e-06     	|  1              	|  1.1399e-06     	|  2.7762e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_epoch_end  	|  1.0561e-06     	|  1              	|  1.0561e-06     	|  2.5721e-07     	|
# |  [LightningModule]ResNetClassifier.on_test_end                                                                                                            	|  9.8092e-07     	|  1              	|  9.8092e-07     	|  2.3889e-07     	|
# |  [Strategy]SingleDeviceStrategy.on_test_end                                                                                                               	|  9.73e-07       	|  1              	|  9.73e-07       	|  2.3696e-07     	|
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test_acc            0.6806449294090271
#         test_auc            0.6912497282028198
#          test_f1            0.7633298635482788
#         test_loss           0.6073537468910217
#         test_prec           0.7321085333824158
#         test_rec             0.797332763671875
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# [{'test_acc': 0.6806449294090271,
#   'test_prec': 0.7321085333824158,
#   'test_rec': 0.797332763671875,
#   'test_f1': 0.7633298635482788,
#   'test_auc': 0.6912497282028198,
#   'test_loss': 0.6073537468910217}]
